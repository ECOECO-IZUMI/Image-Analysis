# %% [markdown]
# <a href="https://colab.research.google.com/github/ECOECO-IZUMI/Image-Analysis/blob/main/%E7%94%BB%E5%83%8F%E8%A7%A3%E6%9E%90sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

img1 = cv2.imread("1.png");
cv2_imshow(img1);
w,h,p= img1.shape;
for i in range(w):
  for j in range(h):
    b1 = img1[i,j,0];
    g1 = img1[i,j,1];
    r1 = img1[i,j,2];

b1,g1,r1
# Out:
# <PIL.Image.Image image mode=RGB size=397x351>
# (np.uint8(32), np.uint8(32), np.uint8(29))

# %%
img2=img1.copy()
for i in range(w):
  for j in range(h):
    img2[i,j,:]=[32,32,29];

cv2_imshow(img2);
# Out:
# <PIL.Image.Image image mode=RGB size=397x351>
